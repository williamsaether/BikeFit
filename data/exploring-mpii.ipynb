# %%
import random
import numpy as np
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from scipy.io import loadmat
import json
import os
import cv2
import matplotlib.pyplot as plt
import h5py
import tensorflow as tf
from tensorflow import keras
from keras import layers
from keras import mixed_precision
# Out:
# C:\Users\willi\anaconda3\envs\tf_gpu\lib\site-packages\h5py\__init__.py:36: UserWarning: h5py is running against HDF5 1.14.6 when it was built against 1.14.5, this may cause problems
#   _warn(("h5py is running against HDF5 {0} when it was built against {1}, "

# %%
mpii_folder = "mpii"
dataset_folder = os.path.join(mpii_folder, "mpii_human_pose_v1")
image_folder = os.path.join(dataset_folder, "images")

# %%
# optional for gpus with lower vram
mixed_precision.set_global_policy('mixed_float16')
# Out:
# INFO:tensorflow:Mixed precision compatibility check (mixed_float16): OK
# Your GPU will likely run quickly with dtype policy mixed_float16 as it has compute capability of at least 7.0. Your GPU: NVIDIA GeForce RTX 3060 Ti, compute capability 8.6

# %%
print("GPUs available:", tf.config.list_physical_devices('GPU'))
# Out:
# GPUs available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## Preparing the data
# The images are .jpg files inside the images folder, while the joints/annotations for the images are located in a MATLAB file (.mat). We need to use the loadmat function to load the MATLAB file into the notebook.

# %%
mat = loadmat(os.path.join(dataset_folder,'mpii_human_pose_v1_u12_1.mat'))
mat = mat['RELEASE']

# %%
data = []

for i, (anno, train) in enumerate(
    zip(mat['annolist'][0,0][0], 
        mat['img_train'][0,0][0])
):
    img_name = anno['image']['name'][0,0][0]
    train = int(train)
    
    for annorect in anno['annorect']:
        if annorect.size < 1 or 'scale' not in str(annorect.dtype):
            continue
            
        for j, annorect in enumerate(annorect):
            if annorect['scale'][0].size < 1:
                continue
                
            scale = float(annorect['scale'][0,0])
            x, y = annorect['objpos'][0,0]
            x = int(x[0,0])
            y = int(y[0,0])
            
            if 'annopoints' in str(anno['annorect'].dtype):
                annopoints = annorect['annopoints']
                if annopoints['point'][0][0].size == 16:
                    points = annopoints[0,0]
                    joint_coords = {}
                    visible_joints = {}
                    
                    for coord in points[0][0]:
                        joint_coords[int(coord['id'][0,0])] = [float(coord['x'][0,0]), float(coord['y'][0,0])]
                        visible_joints[int(coord['id'][0,0])] = coord['is_visible'].item() if (coord['is_visible'].size > 0) else 0
                    
                    category = activity = 'undefined'
                    if mat['act'][0,0][i]['cat_name'][0].size > 0:
                        category = mat['act'][0,0][i]['cat_name'][0][0]
                        activity = mat['act'][0,0][i]['act_name'][0][0]
                    
                    data.append({
                        'filename': img_name,
                        'joint_coords': joint_coords,
                        'visible_joints': visible_joints,
                        'for_training': train,
                        'category': category,
                        'activity': activity,
                        'approx_loc': {
                            'scale': scale,
                            'x': x,
                            'y': y,
                        },
                    })
            else:
                data.append({
                        'filename': img_name,
                        'for_training': train,
                        'approx_loc': {
                            'scale': scale,
                            'x': x,
                            'y': y,
                        }
                    })

# %%
output_json = os.path.join(mpii_folder,'data.json')
file = open(output_json, 'w')
json.dump(data, file, indent=2)

# %% [markdown]
# ## Checkout the data
# Let's show a random image and overlay the joints

# %%
file = open(os.path.join(mpii_folder,'data.json'))
data = json.load(file)

def plot_joints(image_path, coordinates):
    image = cv2.imread(image_path)
    for joint in coordinates:
        cv2.circle(image, (int(joint[0]), int(joint[1])), 5, (0, 0, 255), -1)
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.show()

example = data[240]
img_filename = example.get('filename')
joints = example.get('joint_coords')

joint_coords = []
for joint, coords in joints.items():
    joint_coords.append((coords[0], coords[1]))

plot_joints(os.path.join(image_folder,img_filename), joint_coords)

# %% [markdown]
# ## Preprocessing the data
# We will have to resize and crop the images to the same size, we will also save this into a HDF5 file as it handles large amounts of data very well

# %%
file = open(os.path.join(mpii_folder,'data.json'))
data = json.load(file)

# %%
def preprocess_image(img_path, objpos, scale, img_size=(128,128)):
    img = cv2.imread(img_path)
    h, w, _ = img.shape
    
    crop_size = int(scale * 200) # Scale factor of 200px stated in dataset
    x1, y1 = int(objpos[0] - crop_size // 2), int(objpos[1] - crop_size // 2)
    x2, y2 = x1 + crop_size, y1 + crop_size
    
    x1, y1 = max(0, x1), max(0, y1)
    x2, y2 = min(w, x2), min(h, y2)
    
    # check if the crop is square or not
    # the idea is to pad the image with empty pixels (black) if the coordinates go beyond the image
    crop_width = x2 - x1
    crop_height = y2 - y1
    
    if crop_width != crop_height: # meaning the thought to be cropped image would not be square
        max_dim = max(crop_width, crop_height)
        
        padding_left = (max_dim - crop_width) // 2
        padding_top = (max_dim - crop_height) // 2
        
        padded_img = np.zeros((max_dim, max_dim, 3), dtype=np.uint8)
        padded_img[padding_top:padding_top+crop_height, padding_left:padding_left+crop_width] = img[y1:y2, x1:x2]
        
        cropped_img = padded_img
        x1 = x1 - padding_left
        y1 = y1 - padding_top
        
    else: # the new coordinates are perfectly square
        cropped_img = img[y1:y2, x1:x2]
    
    resized_img = cv2.resize(cropped_img, img_size)
    
    scale_factor = img_size[0] / max(crop_width, crop_height)
    transform_params = (x1, y1, scale_factor)
    
    return resized_img, transform_params

def adjust_keypoints(keypoints, transform_params):
    x1, y1, scale_factor = transform_params
    adjusted_keypoints = np.zeros((16,2), dtype=np.float32)
    
    for key, (x, y) in keypoints.items():
        x_new = (x - x1) * scale_factor
        y_new = (y - y1) * scale_factor
        adjusted_keypoints[int(key)] = [x_new, y_new]
    
    return adjusted_keypoints

def generate_heatmap(image_size, joints, sigma=2): # Inspiration from ChatGPT
    num_joints = len(joints)
    heatmaps = np.zeros((image_size[0], image_size[1], num_joints), dtype=np.float32)
    
    for i, (x,y) in enumerate(joints):
        x = int(x * image_size[1])
        y = int(y * image_size[0])
        
        if x < 0 or y < 0 or x >= image_size[1] or y >= image_size[0]:
            continue
        
        for j in range(image_size[0]):
            for k in range(image_size[1]):
                heatmaps[j, k, i] = np.exp(-((j - y) ** 2 + (k - x) ** 2) / (2 * sigma ** 2))
        
        max_val = np.max(heatmaps[:, :, i])
        if max_val > 0:
            heatmaps[:, :, i] /= max_val  # normalize heatmap intensity

    return heatmaps # should now have shape (128, 128, 16)

# %% [markdown]
# ### Test the functions
# Let's test out the functions by plotting the outputs over the original image

# %%
ann = data[423]

preprocessed_img, transform_params = preprocess_image(
    os.path.join(image_folder, ann['filename']), 
    (ann['approx_loc']['x'], ann['approx_loc']['y']), 
    ann['approx_loc']['scale'])

# Normalize the values
test_image = preprocessed_img
test_joints = adjust_keypoints(ann['joint_coords'], transform_params) / 128.0

# Generate a heatmap for every joint, and then combine them to a single heatmap for visualization purposes
heatmaps = generate_heatmap((128, 128), test_joints)
combined_heatmap = np.sum(heatmaps, axis=-1)

plt.figure(figsize=(6, 6))
plt.imshow(test_image)
plt.imshow(combined_heatmap, cmap="jet", alpha=0.4)

for i, (x, y) in enumerate(test_joints):
    x, y = x * 128, y * 128
    plt.scatter(x, y, c='red', s=10, marker='o')

plt.axis("off")
plt.show()

# %% [markdown]
# ## Create and save a dataset
# Seeing that the functions are working, we can now put this all in a dataset file.
#
# We save it in a HDF5 file, because it's effective when storing complex data structures when it comes to large datasets. We store the images and heatmaps as uint8 scaled between 0 and 255 to minimize file size.

# %%
def create_dataset(dataset, name, for_training):
    num_samples = sum(1 for ann in dataset if ann['for_training'] == for_training)
    
    with h5py.File(os.path.join(mpii_folder,name + '.h5'), 'w') as f:
        img_dataset = f.create_dataset("images", (num_samples, 128, 128, 3), dtype='uint8') # IMG SIZE (128,128,3)
        heatmaps_dataset = f.create_dataset("heatmaps", (num_samples, 128, 128, 16), dtype='uint8') # IMG SIZE + joints
        
        index = 0
        for ann in dataset:
            img_path = os.path.join(image_folder, ann['filename'])
            objpos = (ann['approx_loc']['x'], ann['approx_loc']['y'])
            scale = ann['approx_loc']['scale']
            
            preprocessed_img, transform_params = preprocess_image(img_path, objpos, scale)
            img_dataset[index] = preprocessed_img
            
            if ann['for_training'] == for_training:
                adjusted_keypoints = adjust_keypoints(ann['joint_coords'], transform_params) / 128 # normalize the values
                heatmaps_dataset[index] = (generate_heatmap((128, 128), adjusted_keypoints) * 255).astype(np.uint8) # scale to 0-255
            
            index += 1
            if index >= num_samples: break
    
    print(name + ".h5 successfully created")

create_dataset(data, 'train_dataset', for_training=1)
# Out:
# train_dataset.h5 successfully created

# %% [markdown]
# ## Building a model
# Let's load the dataset first

# %%
with h5py.File(os.path.join(mpii_folder, 'train_dataset.h5'), 'r') as f:
    d_images = np.array(f['images'], dtype=np.float16) / 255.0 # normalize the images to [0,1]
    d_heatmaps = np.array(f['heatmaps'], dtype=np.float16) / 255.0 # normalize the heatmaps to [0,1]
    num_samples = d_images.shape[0]

# %% [markdown]
# ### Loading the dataset file
# If you have enough memory you can directly load the dataset, try the code in the cell below, but if it fails, we will need to load the data from the file using a generator

# %%
dataset = tf.data.Dataset.from_tensor_slices((d_images, d_heatmaps)).batch(16).prefetch(tf.data.AUTOTUNE)

# %% [markdown]
# If the cell above throws an error, we will need to use the generator below:

# %%
def data_generator():
    for i in range(num_samples):
        yield d_images[i], d_heatmaps[i]

dataset = tf.data.Dataset.from_generator(
    data_generator,
    output_signature=(
        tf.TensorSpec(shape=(128, 128, 3), dtype=tf.float16),
        tf.TensorSpec(shape=(128, 128, 16), dtype=tf.float16),
    )
)

# %% [markdown]
# ### Splitting into training and validation datasets
# We now need to split the dataset into two datasets at an 80/20 split. An important part of this is that we have to make sure that we split the dataset before taking out batches and shuffling the dataset, as `.take()` and `.skip()` will not work properly unless we do this.

# %%
train_ratio = 0.8
train_size = int(num_samples * train_ratio)

train_data = dataset.take(train_size).shuffle(num_samples, seed=42).batch(16).prefetch(tf.data.AUTOTUNE)
val_data = dataset.skip(train_size).batch(16).prefetch(tf.data.AUTOTUNE)
print(f"Train samples: {train_size}, Validation samples: {num_samples - train_size}")
# Out:
# Train samples: 15935, Validation samples: 3984

# %% [markdown]
# ### A model that predicts every joint/keypoint
# This was our initial model, but after research we figured out that we need a model that predicts heatmaps of every single joint instead, not one that predicts every joint.

# %%
def build_keypoint_predictor(input_shape, num_keypoints=16):
    inputs = keras.Input(shape=input_shape)
    
    x = layers.Conv2D(64, (3,3), padding='same', activation="relu")(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Conv2D(128, (3,3), padding='same', activation="relu")(x)
    x = layers.BatchNormalization()(x)
    
    shortcut = x
    x = layers.Conv2D(128, (3,3), padding='same', activation="relu")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Conv2D(128, (3,3), padding='same', activation="relu")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Add()([x, shortcut])
    
    shortcut = layers.Conv2D(256, (1,1), padding='same')(x)
    x = layers.Conv2D(256, (3,3), padding='same', activation="relu")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Conv2D(256, (3,3), padding='same', activation="relu")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Add()([x, shortcut])
    
    x = layers.Conv2D(256, (3,3), strides=2, padding='same', activation="relu")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Conv2DTranspose(128, (3,3), strides=2, padding='same')(x)
    x = layers.BatchNormalization()(x)
    
    x = layers.Conv2D(num_keypoints, (1,1), activation="sigmoid")(x)
    x = layers.Flatten()(x)
    x = layers.Dense(num_keypoints * 2)(x)
    outputs = layers.Reshape((num_keypoints, 2))(x)
    
    model = keras.Model(inputs, outputs, name="Simple_Keypoint_Detection")
    return model

# %% [markdown]
# ### A more complicated model
# The model below will predict a heatmap for every joint

# %%
def basic_block(input_tensor, filters, strides=1, dilation_rate=2):
    shortcut = input_tensor
    x = layers.Conv2D(filters, (3,3), strides=strides, padding='same', use_bias=False, dilation_rate=dilation_rate)(input_tensor)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)
    x = layers.Conv2D(filters, (3,3), padding='same', use_bias=False, dilation_rate=dilation_rate)(x)
    x = layers.BatchNormalization()(x)
    if shortcut.shape[-1] != filters:
        shortcut = layers.Conv2D(filters, (1,1), strides=strides, use_bias=False)(shortcut)
        shortcut = layers.BatchNormalization()(shortcut)
    x = layers.Add()([x, shortcut])
    out = layers.ReLU()(x)
    return out

def make_layer(x, block, filters, blocks):
    for _ in range(blocks):
        x = block(x, filters)
    return x

def build_heatmap_model(input_shape=(128,128,3), num_joints=16):
    inputs = keras.Input(shape=input_shape)
    
    x = layers.Conv2D(64, (3,3), strides=1, padding='same', use_bias=False)(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)
    
    x1 = make_layer(x, basic_block, 64, 4)
    x2 = make_layer(x1, basic_block, 128, 2)
    x3 = make_layer(x2, basic_block, 256, 2)
    
    # x2_up = layers.Conv2DTranspose(128, (1,1), padding='same')(x3)
    # x2_up = layers.UpSampling2D(2)(x2_up)
    # x2_concat = layers.Concatenate()([x2_up, x2])
    # 
    # x1_up = layers.Conv2DTranspose(64, (1,1), padding='same')(x2_concat)
    # x1_up = layers.UpSampling2D(2)(x1_up)
    # x1_concat = layers.Concatenate()([x1_up, x1])
    
    output = layers.Conv2D(num_joints, (1,1), padding='same', activation="sigmoid")(x3)
    return keras.Model(inputs, output, name="Heatmap_Detection")

# %% [markdown]
# ### Let's try something different
# The previous model did alright, but we should also explore other model types. We are still going to be using blocks like above, but it will be more advanced.

# %%
def conv_block(x, filters, kernel_size=(3,3), strides=1, activation=True):
    x = layers.Conv2D(filters, kernel_size, strides, padding='same', use_bias=False)(x)
    x = layers.LayerNormalization()(x)
    if activation:
        x = layers.ReLU()(x)
    return x

def residual_block(x, filters):
    skip = x
    x = conv_block(x, filters)
    x = conv_block(x, filters, activation=False)
    if skip.shape[-1] != filters:
        skip = layers.Conv2D(filters, (1,1), use_bias=False)(skip)
        skip = layers.LayerNormalization()(skip)
    x = layers.Add()([x * 0.1, skip])
    x = layers.ReLU()(x)
    return x

def encoder_block(x, filters):
    x = residual_block(x, filters)
    skip = x
    x = layers.MaxPooling2D((2, 2))(x)
    return x, skip

def decoder_block(x, skip, filters):
    x = layers.Conv2DTranspose(filters, (3,3), strides=2, padding='same')(x)
    x = layers.Concatenate()([x, skip])
    x = residual_block(x, filters)
    return x

def build_heatmap_model_advanced(input_shape=(128,128,3), num_joints=16):
    inputs = keras.Input(shape=input_shape)
    
    # Encoder
    x, skip1 = encoder_block(inputs, 64)
    x, skip2 = encoder_block(x, 128)
    x, skip3 = encoder_block(x, 256)
    x, skip4 = encoder_block(x, 512)
    
    # Bottleneck
    x = residual_block(x, 1024)
    
    # Decoder
    x = decoder_block(x, skip4, 512)
    x = decoder_block(x, skip3, 256)
    x = decoder_block(x, skip2, 128)
    x = decoder_block(x, skip1, 64)
    
    outputs = layers.Conv2D(num_joints, (1,1), padding='same', activation="sigmoid")(x)
    return keras.Model(inputs, outputs, name="EncoderDecoder_Heatmap_Detection")

# %% [markdown]
# ### A Stacked Hourglass Network model
# Stacked hourglass networks has proven to be effective for human pose estimation. This architecture has given state-of-the-art results on the MPII dataset and has outcompeted all recent methods.
#
# https://paperswithcode.com/paper/stacked-hourglass-networks-for-human-pose
#
# It is based on this model: https://github.com/ethanyanjiali/deep-vision/blob/master/Hourglass/tensorflow/hourglass104.py

# %%
def bottleneck_block(x, filters, downsample=False):
    skip = x
    if downsample:
        skip = layers.Conv2D(filters, (1,1), strides=1, padding='same', kernel_initializer='he_normal')(skip)
    
    x = layers.BatchNormalization(momentum=0.9)(x)
    x = layers.ReLU()(x)
    x = layers.Conv2D(filters // 2, (1,1), strides=1, padding='same', kernel_initializer='he_normal')(x)
    
    x = layers.BatchNormalization(momentum=0.9)(x)
    x = layers.ReLU()(x)
    x = layers.Conv2D(filters // 2, (3,3), strides=1, padding='same', kernel_initializer='he_normal')(x)
    
    x = layers.BatchNormalization(momentum=0.9)(x)
    x = layers.ReLU()(x)
    x = layers.Conv2D(filters, (1,1), strides=1, padding='same', kernel_initializer='he_normal')(x)
    
    x = layers.Add()([x, skip])
    return x

def hourglass_module(x, filters, depth):
    up = bottleneck_block(x, filters)
    up = bottleneck_block(up, filters)
    
    low = layers.MaxPooling2D((2,2), strides=2)(x)
    low = bottleneck_block(low, filters)
    
    if depth > 1:
        low = hourglass_module(low, filters, depth - 1)
    else:
        low = bottleneck_block(low, filters)
    
    low = bottleneck_block(low, filters)
    up2 = layers.UpSampling2D((2,2))(low)
    
    return up + up2

def build_stacked_hourglass(input_shape=(128,128,3), num_joints=16, stack=4):
    inputs = keras.Input(shape=input_shape)
    
    x = layers.Conv2D(64, (7,7), strides=2, padding='same', kernel_initializer='he_normal')(inputs)
    x = layers.BatchNormalization(momentum=0.9)(x)
    x = layers.ReLU()(x)
    x = bottleneck_block(x, 128, downsample=True)
    x = layers.MaxPooling2D((2,2), strides=2)(x)
    x = bottleneck_block(x, 128, downsample=False)
    x = bottleneck_block(x, 256, downsample=True)
    
    outputs = []
    for i in range(stack):
        hg = hourglass_module(x, 256, depth=4)
        hg = bottleneck_block(hg, 256)
        
        hg = layers.Conv2D(256, (1,1), strides=1, padding='same', kernel_initializer='he_normal')(hg)
        hg = layers.BatchNormalization(momentum=0.9)(hg)
        hg = layers.ReLU()(hg)
        
        if hg.shape[1] == 32: hg = layers.UpSampling2D(size=(4,4), interpolation="bilinear")(hg)  # Upsample from 32x32 to 128x128
        out = layers.Conv2D(num_joints, (1,1), strides=1, padding='same', kernel_initializer='he_normal')(hg)
        outputs.append(out)
        
        # adding the prediction back for next module
        x = layers.Conv2D(256, (1,1), strides=1)(hg)
        x = layers.Conv2D(256, (1,1), strides=1)(out)
        x = layers.Add()([x, hg])
    
    return keras.Model(inputs, outputs, name="StackedHourglass_Detection")

# %% [markdown]
# ### Create a model with a pretrained model
# Let's try out the MobileNetV2 model as the backbone of our model
#
# https://keras.io/examples/vision/keypoint_detection/

# %%
def build_pretrained_model(input_shape=(128,128,3), num_joints=16):
    inputs = layers.Input(shape=input_shape)
    
    base_model = keras.applications.ResNet50(
        weights='imagenet',
        include_top=False,
        input_tensor=inputs,
        pooling=None,
    )
    
    x = base_model.output # Shape will be (4,4,1280) for 128x128
    
    x = layers.Conv2DTranspose(256, (4, 4), strides=(2, 2), padding='same', activation='relu')(x)
    x = layers.Conv2DTranspose(256, (4, 4), strides=(2, 2), padding='same', activation='relu')(x)
    x = layers.Conv2DTranspose(256, (4, 4), strides=(2, 2), padding='same', activation='relu')(x)
    x = layers.Conv2DTranspose(256, (4, 4), strides=(2, 2), padding='same', activation='relu')(x)
    x = layers.Conv2DTranspose(256, (4, 4), strides=(2, 2), padding='same', activation='relu')(x)
    
    outputs = layers.Conv2D(num_joints, (1,1), padding='same', activation="relu")(x)  # (128,128,16)
    
    return keras.Model(base_model.input, outputs, name="ResNet50-Base_Detection")

# %% [markdown]
# ### Compile and fit
# An important part about training is the hyperparameters, and some of the most important ones are optimization algorithm, learning rate, loss function, and epochs.

# %%
model = build_stacked_hourglass()

model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=1e-4), 
    loss='mse',
)

model.summary()
# Out:
# Model: "StackedHourglass_Detection"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_12 (InputLayer)          [(None, 128, 128, 3  0           []
#                                 )]
#
#  conv2d_1682 (Conv2D)           (None, 64, 64, 64)   9472        ['input_12[0][0]']
#
#  batch_normalization_1588 (Batc  (None, 64, 64, 64)  256         ['conv2d_1682[0][0]']
#  hNormalization)
#
#  re_lu_1587 (ReLU)              (None, 64, 64, 64)   0           ['batch_normalization_1588[0][0]'
#                                                                  ]
#
#  batch_normalization_1589 (Batc  (None, 64, 64, 64)  256         ['re_lu_1587[0][0]']
#  hNormalization)
#
#  re_lu_1588 (ReLU)              (None, 64, 64, 64)   0           ['batch_normalization_1589[0][0]'
#                                                                  ]
#
#  conv2d_1684 (Conv2D)           (None, 64, 64, 64)   4160        ['re_lu_1588[0][0]']
#
#  batch_normalization_1590 (Batc  (None, 64, 64, 64)  256         ['conv2d_1684[0][0]']
#  hNormalization)
#
#  re_lu_1589 (ReLU)              (None, 64, 64, 64)   0           ['batch_normalization_1590[0][0]'
#                                                                  ]
#
#  conv2d_1685 (Conv2D)           (None, 64, 64, 64)   36928       ['re_lu_1589[0][0]']
#
#  batch_normalization_1591 (Batc  (None, 64, 64, 64)  256         ['conv2d_1685[0][0]']
#  hNormalization)
#
#  re_lu_1590 (ReLU)              (None, 64, 64, 64)   0           ['batch_normalization_1591[0][0]'
#                                                                  ]
#
#  conv2d_1686 (Conv2D)           (None, 64, 64, 128)  8320        ['re_lu_1590[0][0]']
#
#  conv2d_1683 (Conv2D)           (None, 64, 64, 128)  8320        ['re_lu_1587[0][0]']
#
#  add_575 (Add)                  (None, 64, 64, 128)  0           ['conv2d_1686[0][0]',
#                                                                   'conv2d_1683[0][0]']
#
#  max_pooling2d_117 (MaxPooling2  (None, 32, 32, 128)  0          ['add_575[0][0]']
#  D)
#
#  batch_normalization_1592 (Batc  (None, 32, 32, 128)  512        ['max_pooling2d_117[0][0]']
#  hNormalization)
#
#  re_lu_1591 (ReLU)              (None, 32, 32, 128)  0           ['batch_normalization_1592[0][0]'
#                                                                  ]
#
#  conv2d_1687 (Conv2D)           (None, 32, 32, 64)   8256        ['re_lu_1591[0][0]']
#
#  batch_normalization_1593 (Batc  (None, 32, 32, 64)  256         ['conv2d_1687[0][0]']
#  hNormalization)
#
#  re_lu_1592 (ReLU)              (None, 32, 32, 64)   0           ['batch_normalization_1593[0][0]'
#                                                                  ]
#
#  conv2d_1688 (Conv2D)           (None, 32, 32, 64)   36928       ['re_lu_1592[0][0]']
#
#  batch_normalization_1594 (Batc  (None, 32, 32, 64)  256         ['conv2d_1688[0][0]']
#  hNormalization)
#
#  re_lu_1593 (ReLU)              (None, 32, 32, 64)   0           ['batch_normalization_1594[0][0]'
#                                                                  ]
#
#  conv2d_1689 (Conv2D)           (None, 32, 32, 128)  8320        ['re_lu_1593[0][0]']
#
#  add_576 (Add)                  (None, 32, 32, 128)  0           ['conv2d_1689[0][0]',
#                                                                   'max_pooling2d_117[0][0]']
#
#  batch_normalization_1595 (Batc  (None, 32, 32, 128)  512        ['add_576[0][0]']
#  hNormalization)
#
#  re_lu_1594 (ReLU)              (None, 32, 32, 128)  0           ['batch_normalization_1595[0][0]'
#                                                                  ]
#
#  conv2d_1691 (Conv2D)           (None, 32, 32, 128)  16512       ['re_lu_1594[0][0]']
#
#  batch_normalization_1596 (Batc  (None, 32, 32, 128)  512        ['conv2d_1691[0][0]']
#  hNormalization)
#
#  re_lu_1595 (ReLU)              (None, 32, 32, 128)  0           ['batch_normalization_1596[0][0]'
#                                                                  ]
#
#  conv2d_1692 (Conv2D)           (None, 32, 32, 128)  147584      ['re_lu_1595[0][0]']
#
#  batch_normalization_1597 (Batc  (None, 32, 32, 128)  512        ['conv2d_1692[0][0]']
#  hNormalization)
#
#  re_lu_1596 (ReLU)              (None, 32, 32, 128)  0           ['batch_normalization_1597[0][0]'
#                                                                  ]
#
#  conv2d_1693 (Conv2D)           (None, 32, 32, 256)  33024       ['re_lu_1596[0][0]']
#
#  conv2d_1690 (Conv2D)           (None, 32, 32, 256)  33024       ['add_576[0][0]']
#
#  add_577 (Add)                  (None, 32, 32, 256)  0           ['conv2d_1693[0][0]',
#                                                                   'conv2d_1690[0][0]']
#
#  max_pooling2d_118 (MaxPooling2  (None, 16, 16, 256)  0          ['add_577[0][0]']
#  D)
#
#  batch_normalization_1604 (Batc  (None, 16, 16, 256)  1024       ['max_pooling2d_118[0][0]']
#  hNormalization)
#
#  re_lu_1603 (ReLU)              (None, 16, 16, 256)  0           ['batch_normalization_1604[0][0]'
#                                                                  ]
#
#  conv2d_1700 (Conv2D)           (None, 16, 16, 128)  32896       ['re_lu_1603[0][0]']
#
#  batch_normalization_1605 (Batc  (None, 16, 16, 128)  512        ['conv2d_1700[0][0]']
#  hNormalization)
#
#  re_lu_1604 (ReLU)              (None, 16, 16, 128)  0           ['batch_normalization_1605[0][0]'
#                                                                  ]
#
#  conv2d_1701 (Conv2D)           (None, 16, 16, 128)  147584      ['re_lu_1604[0][0]']
#
#  batch_normalization_1606 (Batc  (None, 16, 16, 128)  512        ['conv2d_1701[0][0]']
#  hNormalization)
#
#  re_lu_1605 (ReLU)              (None, 16, 16, 128)  0           ['batch_normalization_1606[0][0]'
#                                                                  ]
#
#  conv2d_1702 (Conv2D)           (None, 16, 16, 256)  33024       ['re_lu_1605[0][0]']
#
#  add_580 (Add)                  (None, 16, 16, 256)  0           ['conv2d_1702[0][0]',
#                                                                   'max_pooling2d_118[0][0]']
#
#  max_pooling2d_119 (MaxPooling2  (None, 8, 8, 256)   0           ['add_580[0][0]']
#  D)
#
#  batch_normalization_1613 (Batc  (None, 8, 8, 256)   1024        ['max_pooling2d_119[0][0]']
#  hNormalization)
#
#  re_lu_1612 (ReLU)              (None, 8, 8, 256)    0           ['batch_normalization_1613[0][0]'
#                                                                  ]
#
#  conv2d_1709 (Conv2D)           (None, 8, 8, 128)    32896       ['re_lu_1612[0][0]']
#
#  batch_normalization_1614 (Batc  (None, 8, 8, 128)   512         ['conv2d_1709[0][0]']
#  hNormalization)
#
#  re_lu_1613 (ReLU)              (None, 8, 8, 128)    0           ['batch_normalization_1614[0][0]'
#                                                                  ]
#
#  conv2d_1710 (Conv2D)           (None, 8, 8, 128)    147584      ['re_lu_1613[0][0]']
#
#  batch_normalization_1615 (Batc  (None, 8, 8, 128)   512         ['conv2d_1710[0][0]']
#  hNormalization)
#
#  re_lu_1614 (ReLU)              (None, 8, 8, 128)    0           ['batch_normalization_1615[0][0]'
#                                                                  ]
#
#  conv2d_1711 (Conv2D)           (None, 8, 8, 256)    33024       ['re_lu_1614[0][0]']
#
#  add_583 (Add)                  (None, 8, 8, 256)    0           ['conv2d_1711[0][0]',
#                                                                   'max_pooling2d_119[0][0]']
#
#  max_pooling2d_120 (MaxPooling2  (None, 4, 4, 256)   0           ['add_583[0][0]']
#  D)
#
#  batch_normalization_1622 (Batc  (None, 4, 4, 256)   1024        ['max_pooling2d_120[0][0]']
#  hNormalization)
#
#  re_lu_1621 (ReLU)              (None, 4, 4, 256)    0           ['batch_normalization_1622[0][0]'
#                                                                  ]
#
#  conv2d_1718 (Conv2D)           (None, 4, 4, 128)    32896       ['re_lu_1621[0][0]']
#
#  batch_normalization_1623 (Batc  (None, 4, 4, 128)   512         ['conv2d_1718[0][0]']
#  hNormalization)
#
#  re_lu_1622 (ReLU)              (None, 4, 4, 128)    0           ['batch_normalization_1623[0][0]'
#                                                                  ]
#
#  conv2d_1719 (Conv2D)           (None, 4, 4, 128)    147584      ['re_lu_1622[0][0]']
#
#  batch_normalization_1624 (Batc  (None, 4, 4, 128)   512         ['conv2d_1719[0][0]']
#  hNormalization)
#
#  re_lu_1623 (ReLU)              (None, 4, 4, 128)    0           ['batch_normalization_1624[0][0]'
#                                                                  ]
#
#  conv2d_1720 (Conv2D)           (None, 4, 4, 256)    33024       ['re_lu_1623[0][0]']
#
#  add_586 (Add)                  (None, 4, 4, 256)    0           ['conv2d_1720[0][0]',
#                                                                   'max_pooling2d_120[0][0]']
#
#  max_pooling2d_121 (MaxPooling2  (None, 2, 2, 256)   0           ['add_586[0][0]']
#  D)
#
#  batch_normalization_1631 (Batc  (None, 2, 2, 256)   1024        ['max_pooling2d_121[0][0]']
#  hNormalization)
#
#  re_lu_1630 (ReLU)              (None, 2, 2, 256)    0           ['batch_normalization_1631[0][0]'
#                                                                  ]
#
#  conv2d_1727 (Conv2D)           (None, 2, 2, 128)    32896       ['re_lu_1630[0][0]']
#
#  batch_normalization_1632 (Batc  (None, 2, 2, 128)   512         ['conv2d_1727[0][0]']
#  hNormalization)
#
#  re_lu_1631 (ReLU)              (None, 2, 2, 128)    0           ['batch_normalization_1632[0][0]'
#                                                                  ]
#
#  conv2d_1728 (Conv2D)           (None, 2, 2, 128)    147584      ['re_lu_1631[0][0]']
#
#  batch_normalization_1633 (Batc  (None, 2, 2, 128)   512         ['conv2d_1728[0][0]']
#  hNormalization)
#
#  re_lu_1632 (ReLU)              (None, 2, 2, 128)    0           ['batch_normalization_1633[0][0]'
#                                                                  ]
#
#  conv2d_1729 (Conv2D)           (None, 2, 2, 256)    33024       ['re_lu_1632[0][0]']
#
#  add_589 (Add)                  (None, 2, 2, 256)    0           ['conv2d_1729[0][0]',
#                                                                   'max_pooling2d_121[0][0]']
#
#  batch_normalization_1634 (Batc  (None, 2, 2, 256)   1024        ['add_589[0][0]']
#  hNormalization)
#
#  batch_normalization_1625 (Batc  (None, 4, 4, 256)   1024        ['add_586[0][0]']
#  hNormalization)
#
#  re_lu_1633 (ReLU)              (None, 2, 2, 256)    0           ['batch_normalization_1634[0][0]'
#                                                                  ]
#
#  re_lu_1624 (ReLU)              (None, 4, 4, 256)    0           ['batch_normalization_1625[0][0]'
#                                                                  ]
#
#  conv2d_1730 (Conv2D)           (None, 2, 2, 128)    32896       ['re_lu_1633[0][0]']
#
#  conv2d_1721 (Conv2D)           (None, 4, 4, 128)    32896       ['re_lu_1624[0][0]']
#
#  batch_normalization_1635 (Batc  (None, 2, 2, 128)   512         ['conv2d_1730[0][0]']
#  hNormalization)
#
#  batch_normalization_1626 (Batc  (None, 4, 4, 128)   512         ['conv2d_1721[0][0]']
#  hNormalization)
#
#  re_lu_1634 (ReLU)              (None, 2, 2, 128)    0           ['batch_normalization_1635[0][0]'
#                                                                  ]
#
#  re_lu_1625 (ReLU)              (None, 4, 4, 128)    0           ['batch_normalization_1626[0][0]'
#                                                                  ]
#
#  conv2d_1731 (Conv2D)           (None, 2, 2, 128)    147584      ['re_lu_1634[0][0]']
#
#  conv2d_1722 (Conv2D)           (None, 4, 4, 128)    147584      ['re_lu_1625[0][0]']
#
#  batch_normalization_1636 (Batc  (None, 2, 2, 128)   512         ['conv2d_1731[0][0]']
#  hNormalization)
#
#  batch_normalization_1627 (Batc  (None, 4, 4, 128)   512         ['conv2d_1722[0][0]']
#  hNormalization)
#
#  re_lu_1635 (ReLU)              (None, 2, 2, 128)    0           ['batch_normalization_1636[0][0]'
#                                                                  ]
#
#  re_lu_1626 (ReLU)              (None, 4, 4, 128)    0           ['batch_normalization_1627[0][0]'
#                                                                  ]
#
#  conv2d_1732 (Conv2D)           (None, 2, 2, 256)    33024       ['re_lu_1635[0][0]']
#
#  conv2d_1723 (Conv2D)           (None, 4, 4, 256)    33024       ['re_lu_1626[0][0]']
#
#  add_590 (Add)                  (None, 2, 2, 256)    0           ['conv2d_1732[0][0]',
#                                                                   'add_589[0][0]']
#
#  add_587 (Add)                  (None, 4, 4, 256)    0           ['conv2d_1723[0][0]',
#                                                                   'add_586[0][0]']
#
#  batch_normalization_1637 (Batc  (None, 2, 2, 256)   1024        ['add_590[0][0]']
#  hNormalization)
#
#  batch_normalization_1628 (Batc  (None, 4, 4, 256)   1024        ['add_587[0][0]']
#  hNormalization)
#
#  re_lu_1636 (ReLU)              (None, 2, 2, 256)    0           ['batch_normalization_1637[0][0]'
#                                                                  ]
#
#  re_lu_1627 (ReLU)              (None, 4, 4, 256)    0           ['batch_normalization_1628[0][0]'
#                                                                  ]
#
#  conv2d_1733 (Conv2D)           (None, 2, 2, 128)    32896       ['re_lu_1636[0][0]']
#
#  batch_normalization_1616 (Batc  (None, 8, 8, 256)   1024        ['add_583[0][0]']
#  hNormalization)
#
#  conv2d_1724 (Conv2D)           (None, 4, 4, 128)    32896       ['re_lu_1627[0][0]']
#
#  batch_normalization_1638 (Batc  (None, 2, 2, 128)   512         ['conv2d_1733[0][0]']
#  hNormalization)
#
#  re_lu_1615 (ReLU)              (None, 8, 8, 256)    0           ['batch_normalization_1616[0][0]'
#                                                                  ]
#
#  batch_normalization_1629 (Batc  (None, 4, 4, 128)   512         ['conv2d_1724[0][0]']
#  hNormalization)
#
#  re_lu_1637 (ReLU)              (None, 2, 2, 128)    0           ['batch_normalization_1638[0][0]'
#                                                                  ]
#
#  conv2d_1712 (Conv2D)           (None, 8, 8, 128)    32896       ['re_lu_1615[0][0]']
#
#  re_lu_1628 (ReLU)              (None, 4, 4, 128)    0           ['batch_normalization_1629[0][0]'
#                                                                  ]
#
#  conv2d_1734 (Conv2D)           (None, 2, 2, 128)    147584      ['re_lu_1637[0][0]']
#
#  batch_normalization_1617 (Batc  (None, 8, 8, 128)   512         ['conv2d_1712[0][0]']
#  hNormalization)
#
#  conv2d_1725 (Conv2D)           (None, 4, 4, 128)    147584      ['re_lu_1628[0][0]']
#
#  batch_normalization_1639 (Batc  (None, 2, 2, 128)   512         ['conv2d_1734[0][0]']
#  hNormalization)
#
#  re_lu_1616 (ReLU)              (None, 8, 8, 128)    0           ['batch_normalization_1617[0][0]'
#                                                                  ]
#
#  batch_normalization_1630 (Batc  (None, 4, 4, 128)   512         ['conv2d_1725[0][0]']
#  hNormalization)
#
#  re_lu_1638 (ReLU)              (None, 2, 2, 128)    0           ['batch_normalization_1639[0][0]'
#                                                                  ]
#
#  conv2d_1713 (Conv2D)           (None, 8, 8, 128)    147584      ['re_lu_1616[0][0]']
#
#  re_lu_1629 (ReLU)              (None, 4, 4, 128)    0           ['batch_normalization_1630[0][0]'
#                                                                  ]
#
#  conv2d_1735 (Conv2D)           (None, 2, 2, 256)    33024       ['re_lu_1638[0][0]']
#
#  batch_normalization_1618 (Batc  (None, 8, 8, 128)   512         ['conv2d_1713[0][0]']
#  hNormalization)
#
#  conv2d_1726 (Conv2D)           (None, 4, 4, 256)    33024       ['re_lu_1629[0][0]']
#
#  add_591 (Add)                  (None, 2, 2, 256)    0           ['conv2d_1735[0][0]',
#                                                                   'add_590[0][0]']
#
#  re_lu_1617 (ReLU)              (None, 8, 8, 128)    0           ['batch_normalization_1618[0][0]'
#                                                                  ]
#
#  add_588 (Add)                  (None, 4, 4, 256)    0           ['conv2d_1726[0][0]',
#                                                                   'add_587[0][0]']
#
#  up_sampling2d_118 (UpSampling2  (None, 4, 4, 256)   0           ['add_591[0][0]']
#  D)
#
#  conv2d_1714 (Conv2D)           (None, 8, 8, 256)    33024       ['re_lu_1617[0][0]']
#
#  tf.__operators__.add_76 (TFOpL  (None, 4, 4, 256)   0           ['add_588[0][0]',
#  ambda)                                                           'up_sampling2d_118[0][0]']
#
#  add_584 (Add)                  (None, 8, 8, 256)    0           ['conv2d_1714[0][0]',
#                                                                   'add_583[0][0]']
#
#  batch_normalization_1640 (Batc  (None, 4, 4, 256)   1024        ['tf.__operators__.add_76[0][0]']
#  hNormalization)
#
#  batch_normalization_1619 (Batc  (None, 8, 8, 256)   1024        ['add_584[0][0]']
#  hNormalization)
#
#  re_lu_1639 (ReLU)              (None, 4, 4, 256)    0           ['batch_normalization_1640[0][0]'
#                                                                  ]
#
#  re_lu_1618 (ReLU)              (None, 8, 8, 256)    0           ['batch_normalization_1619[0][0]'
#                                                                  ]
#
#  conv2d_1736 (Conv2D)           (None, 4, 4, 128)    32896       ['re_lu_1639[0][0]']
#
#  batch_normalization_1607 (Batc  (None, 16, 16, 256)  1024       ['add_580[0][0]']
#  hNormalization)
#
#  conv2d_1715 (Conv2D)           (None, 8, 8, 128)    32896       ['re_lu_1618[0][0]']
#
#  batch_normalization_1641 (Batc  (None, 4, 4, 128)   512         ['conv2d_1736[0][0]']
#  hNormalization)
#
#  re_lu_1606 (ReLU)              (None, 16, 16, 256)  0           ['batch_normalization_1607[0][0]'
#                                                                  ]
#
#  batch_normalization_1620 (Batc  (None, 8, 8, 128)   512         ['conv2d_1715[0][0]']
#  hNormalization)
#
#  re_lu_1640 (ReLU)              (None, 4, 4, 128)    0           ['batch_normalization_1641[0][0]'
#                                                                  ]
#
#  conv2d_1703 (Conv2D)           (None, 16, 16, 128)  32896       ['re_lu_1606[0][0]']
#
#  re_lu_1619 (ReLU)              (None, 8, 8, 128)    0           ['batch_normalization_1620[0][0]'
#                                                                  ]
#
#  conv2d_1737 (Conv2D)           (None, 4, 4, 128)    147584      ['re_lu_1640[0][0]']
#
#  batch_normalization_1608 (Batc  (None, 16, 16, 128)  512        ['conv2d_1703[0][0]']
#  hNormalization)
#
#  conv2d_1716 (Conv2D)           (None, 8, 8, 128)    147584      ['re_lu_1619[0][0]']
#
#  batch_normalization_1642 (Batc  (None, 4, 4, 128)   512         ['conv2d_1737[0][0]']
#  hNormalization)
#
#  re_lu_1607 (ReLU)              (None, 16, 16, 128)  0           ['batch_normalization_1608[0][0]'
#                                                                  ]
#
#  batch_normalization_1621 (Batc  (None, 8, 8, 128)   512         ['conv2d_1716[0][0]']
#  hNormalization)
#
#  re_lu_1641 (ReLU)              (None, 4, 4, 128)    0           ['batch_normalization_1642[0][0]'
#                                                                  ]
#
#  conv2d_1704 (Conv2D)           (None, 16, 16, 128)  147584      ['re_lu_1607[0][0]']
#
#  re_lu_1620 (ReLU)              (None, 8, 8, 128)    0           ['batch_normalization_1621[0][0]'
#                                                                  ]
#
#  conv2d_1738 (Conv2D)           (None, 4, 4, 256)    33024       ['re_lu_1641[0][0]']
#
#  batch_normalization_1609 (Batc  (None, 16, 16, 128)  512        ['conv2d_1704[0][0]']
#  hNormalization)
#
#  conv2d_1717 (Conv2D)           (None, 8, 8, 256)    33024       ['re_lu_1620[0][0]']
#
#  add_592 (Add)                  (None, 4, 4, 256)    0           ['conv2d_1738[0][0]',
#                                                                   'tf.__operators__.add_76[0][0]']
#
#  re_lu_1608 (ReLU)              (None, 16, 16, 128)  0           ['batch_normalization_1609[0][0]'
#                                                                  ]
#
#  add_585 (Add)                  (None, 8, 8, 256)    0           ['conv2d_1717[0][0]',
#                                                                   'add_584[0][0]']
#
#  up_sampling2d_119 (UpSampling2  (None, 8, 8, 256)   0           ['add_592[0][0]']
#  D)
#
#  conv2d_1705 (Conv2D)           (None, 16, 16, 256)  33024       ['re_lu_1608[0][0]']
#
#  tf.__operators__.add_77 (TFOpL  (None, 8, 8, 256)   0           ['add_585[0][0]',
#  ambda)                                                           'up_sampling2d_119[0][0]']
#
#  add_581 (Add)                  (None, 16, 16, 256)  0           ['conv2d_1705[0][0]',
#                                                                   'add_580[0][0]']
#
#  batch_normalization_1643 (Batc  (None, 8, 8, 256)   1024        ['tf.__operators__.add_77[0][0]']
#  hNormalization)
#
#  batch_normalization_1610 (Batc  (None, 16, 16, 256)  1024       ['add_581[0][0]']
#  hNormalization)
#
#  re_lu_1642 (ReLU)              (None, 8, 8, 256)    0           ['batch_normalization_1643[0][0]'
#                                                                  ]
#
#  re_lu_1609 (ReLU)              (None, 16, 16, 256)  0           ['batch_normalization_1610[0][0]'
#                                                                  ]
#
#  conv2d_1739 (Conv2D)           (None, 8, 8, 128)    32896       ['re_lu_1642[0][0]']
#
#  batch_normalization_1598 (Batc  (None, 32, 32, 256)  1024       ['add_577[0][0]']
#  hNormalization)
#
#  conv2d_1706 (Conv2D)           (None, 16, 16, 128)  32896       ['re_lu_1609[0][0]']
#
#  batch_normalization_1644 (Batc  (None, 8, 8, 128)   512         ['conv2d_1739[0][0]']
#  hNormalization)
#
#  re_lu_1597 (ReLU)              (None, 32, 32, 256)  0           ['batch_normalization_1598[0][0]'
#                                                                  ]
#
#  batch_normalization_1611 (Batc  (None, 16, 16, 128)  512        ['conv2d_1706[0][0]']
#  hNormalization)
#
#  re_lu_1643 (ReLU)              (None, 8, 8, 128)    0           ['batch_normalization_1644[0][0]'
#                                                                  ]
#
#  conv2d_1694 (Conv2D)           (None, 32, 32, 128)  32896       ['re_lu_1597[0][0]']
#
#  re_lu_1610 (ReLU)              (None, 16, 16, 128)  0           ['batch_normalization_1611[0][0]'
# ...
#  conv2d_1914 (Conv2D)           (None, 32, 32, 128)  147584      ['re_lu_1808[0][0]']
#
#  batch_normalization_1764 (Batc  (None, 128, 128, 12  512        ['conv2d_1868[0][0]']
#  hNormalization)                8)
#
#  conv2d_1881 (Conv2D)           (None, 64, 64, 128)  147584      ['re_lu_1775[0][0]']
#
#  batch_normalization_1810 (Batc  (None, 32, 32, 128)  512        ['conv2d_1914[0][0]']
#  hNormalization)
#
#  re_lu_1763 (ReLU)              (None, 128, 128, 12  0           ['batch_normalization_1764[0][0]'
#                                 8)                               ]
#
#  batch_normalization_1777 (Batc  (None, 64, 64, 128)  512        ['conv2d_1881[0][0]']
#  hNormalization)
#
#  re_lu_1809 (ReLU)              (None, 32, 32, 128)  0           ['batch_normalization_1810[0][0]'
#                                                                  ]
#
#  conv2d_1869 (Conv2D)           (None, 128, 128, 12  147584      ['re_lu_1763[0][0]']
#                                 8)
#
#  re_lu_1776 (ReLU)              (None, 64, 64, 128)  0           ['batch_normalization_1777[0][0]'
#                                                                  ]
#
#  conv2d_1915 (Conv2D)           (None, 32, 32, 256)  33024       ['re_lu_1809[0][0]']
#
#  batch_normalization_1765 (Batc  (None, 128, 128, 12  512        ['conv2d_1869[0][0]']
#  hNormalization)                8)
#
#  conv2d_1882 (Conv2D)           (None, 64, 64, 256)  33024       ['re_lu_1776[0][0]']
#
#  add_650 (Add)                  (None, 32, 32, 256)  0           ['conv2d_1915[0][0]',
#                                                                   'tf.__operators__.add_89[0][0]']
#
#  re_lu_1764 (ReLU)              (None, 128, 128, 12  0           ['batch_normalization_1765[0][0]'
#                                 8)                               ]
#
#  add_639 (Add)                  (None, 64, 64, 256)  0           ['conv2d_1882[0][0]',
#                                                                   'add_638[0][0]']
#
#  up_sampling2d_133 (UpSampling2  (None, 64, 64, 256)  0          ['add_650[0][0]']
#  D)
#
#  conv2d_1870 (Conv2D)           (None, 128, 128, 25  33024       ['re_lu_1764[0][0]']
#                                 6)
#
#  tf.__operators__.add_90 (TFOpL  (None, 64, 64, 256)  0          ['add_639[0][0]',
#  ambda)                                                           'up_sampling2d_133[0][0]']
#
#  add_635 (Add)                  (None, 128, 128, 25  0           ['conv2d_1870[0][0]',
#                                 6)                                'add_634[0][0]']
#
#  batch_normalization_1811 (Batc  (None, 64, 64, 256)  1024       ['tf.__operators__.add_90[0][0]']
#  hNormalization)
#
#  batch_normalization_1766 (Batc  (None, 128, 128, 25  1024       ['add_635[0][0]']
#  hNormalization)                6)
#
#  re_lu_1810 (ReLU)              (None, 64, 64, 256)  0           ['batch_normalization_1811[0][0]'
#                                                                  ]
#
#  re_lu_1765 (ReLU)              (None, 128, 128, 25  0           ['batch_normalization_1766[0][0]'
#                                 6)                               ]
#
#  conv2d_1916 (Conv2D)           (None, 64, 64, 128)  32896       ['re_lu_1810[0][0]']
#
#  conv2d_1871 (Conv2D)           (None, 128, 128, 12  32896       ['re_lu_1765[0][0]']
#                                 8)
#
#  batch_normalization_1812 (Batc  (None, 64, 64, 128)  512        ['conv2d_1916[0][0]']
#  hNormalization)
#
#  batch_normalization_1767 (Batc  (None, 128, 128, 12  512        ['conv2d_1871[0][0]']
#  hNormalization)                8)
#
#  re_lu_1811 (ReLU)              (None, 64, 64, 128)  0           ['batch_normalization_1812[0][0]'
#                                                                  ]
#
#  re_lu_1766 (ReLU)              (None, 128, 128, 12  0           ['batch_normalization_1767[0][0]'
#                                 8)                               ]
#
#  conv2d_1917 (Conv2D)           (None, 64, 64, 128)  147584      ['re_lu_1811[0][0]']
#
#  conv2d_1872 (Conv2D)           (None, 128, 128, 12  147584      ['re_lu_1766[0][0]']
#                                 8)
#
#  batch_normalization_1813 (Batc  (None, 64, 64, 128)  512        ['conv2d_1917[0][0]']
#  hNormalization)
#
#  batch_normalization_1768 (Batc  (None, 128, 128, 12  512        ['conv2d_1872[0][0]']
#  hNormalization)                8)
#
#  re_lu_1812 (ReLU)              (None, 64, 64, 128)  0           ['batch_normalization_1813[0][0]'
#                                                                  ]
#
#  re_lu_1767 (ReLU)              (None, 128, 128, 12  0           ['batch_normalization_1768[0][0]'
#                                 8)                               ]
#
#  conv2d_1918 (Conv2D)           (None, 64, 64, 256)  33024       ['re_lu_1812[0][0]']
#
#  conv2d_1873 (Conv2D)           (None, 128, 128, 25  33024       ['re_lu_1767[0][0]']
#                                 6)
#
#  add_651 (Add)                  (None, 64, 64, 256)  0           ['conv2d_1918[0][0]',
#                                                                   'tf.__operators__.add_90[0][0]']
#
#  add_636 (Add)                  (None, 128, 128, 25  0           ['conv2d_1873[0][0]',
#                                 6)                                'add_635[0][0]']
#
#  up_sampling2d_134 (UpSampling2  (None, 128, 128, 25  0          ['add_651[0][0]']
#  D)                             6)
#
#  tf.__operators__.add_91 (TFOpL  (None, 128, 128, 25  0          ['add_636[0][0]',
#  ambda)                         6)                                'up_sampling2d_134[0][0]']
#
#  batch_normalization_1814 (Batc  (None, 128, 128, 25  1024       ['tf.__operators__.add_91[0][0]']
#  hNormalization)                6)
#
#  re_lu_1813 (ReLU)              (None, 128, 128, 25  0           ['batch_normalization_1814[0][0]'
#                                 6)                               ]
#
#  conv2d_1919 (Conv2D)           (None, 128, 128, 12  32896       ['re_lu_1813[0][0]']
#                                 8)
#
#  batch_normalization_1815 (Batc  (None, 128, 128, 12  512        ['conv2d_1919[0][0]']
#  hNormalization)                8)
#
#  re_lu_1814 (ReLU)              (None, 128, 128, 12  0           ['batch_normalization_1815[0][0]'
#                                 8)                               ]
#
#  conv2d_1920 (Conv2D)           (None, 128, 128, 12  147584      ['re_lu_1814[0][0]']
#                                 8)
#
#  batch_normalization_1816 (Batc  (None, 128, 128, 12  512        ['conv2d_1920[0][0]']
#  hNormalization)                8)
#
#  re_lu_1815 (ReLU)              (None, 128, 128, 12  0           ['batch_normalization_1816[0][0]'
#                                 8)                               ]
#
#  conv2d_1921 (Conv2D)           (None, 128, 128, 25  33024       ['re_lu_1815[0][0]']
#                                 6)
#
#  add_652 (Add)                  (None, 128, 128, 25  0           ['conv2d_1921[0][0]',
#                                 6)                                'tf.__operators__.add_91[0][0]']
#
#  conv2d_1922 (Conv2D)           (None, 128, 128, 25  65792       ['add_652[0][0]']
#                                 6)
#
#  batch_normalization_1817 (Batc  (None, 128, 128, 25  1024       ['conv2d_1922[0][0]']
#  hNormalization)                6)
#
#  re_lu_1816 (ReLU)              (None, 128, 128, 25  0           ['batch_normalization_1817[0][0]'
#                                 6)                               ]
#
#  conv2d_1923 (Conv2D)           (None, 128, 128, 16  4112        ['re_lu_1816[0][0]']
#                                 )
#
# ==================================================================================================
# Total params: 16,170,944
# Trainable params: 16,093,376
# Non-trainable params: 77,568
# __________________________________________________________________________________________________

# %%
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=1,
    callbacks=[
        EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, verbose=1),
        ModelCheckpoint("best-resnet-model_before-data-aug.h5", monitor="val_loss", save_best_only=True),
        ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6, verbose=1),
    ]
)

# %%
# We should always save our model
model.save('model_heatmap_resnet50_lr1e3-mse-mae_e10-train-val-early-reducelr.keras')
np.save('history-resnet.npy', history)

# %%
train_loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(train_loss) + 1)

# Plot
plt.figure(figsize=(8, 5))
plt.plot(epochs, train_loss, 'bo-', label='Training Loss')  # 'bo-' makes blue dots & line
plt.plot(epochs, val_loss, 'r^-', label='Validation Loss')  # 'r^-' makes red triangles & line
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training vs Validation Loss Curve')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## Let's test the model
# We will now use the model to predict heatmaps from a random test image, but before then we need to preprocess the test image as well

# %%
# Optional, load the model from storage
model = keras.models.load_model('model_heatmap_data-aug.keras')

# %%
data = json.load(open(os.path.join(mpii_folder,'data.json')))
joints_list = json.load(open(os.path.join(mpii_folder,'joints.json')))

# %%
testdata = []
for ann in data:
    if ann['for_training'] == 0:
        testdata.append(ann)

color_map = ['#ff9e9e','#ff6161','#ff0000','#ffb700','#ffcf54','#ffe49e','#000','#9000ff','#c06eff','#e2bdff','#b3ffd9','#5effaf','#00ff1e','#0015ff','#4252ff','#808aff']

def preprocess_test_image(test_image):
    image, _ = preprocess_image(
        os.path.join(image_folder, test_image['filename']), 
        (test_image['approx_loc']['x'], test_image['approx_loc']['y']), 
        test_image['approx_loc']['scale']
    )
    
    image = image / 255.0
    return image

def extract_joints(heatmaps):
    coords = []
    for i in range(heatmaps.shape[-1]):
        heatmap = heatmaps[..., i]
        heatmap = tf.nn.softmax(tf.reshape(heatmap, [-1]))
        idx = tf.argmax(heatmap, axis=0)
        y, x = tf.unravel_index(idx, (heatmaps.shape[0], heatmaps.shape[1]))
        coords.append([x.numpy(), y.numpy()])
    return np.array(coords)

def extract_and_plot_joints(image, heatmaps):
    extracted_joints = extract_joints(heatmaps)
    
    plt.figure(figsize=(6, 6))
    plt.imshow(cv2.cvtColor(np.float32(image), cv2.COLOR_BGR2RGB))
    # plt.imshow(np.sum(heatmaps, axis=-1), cmap="jet", alpha=0.4)
    
    for i, (x, y) in enumerate(extracted_joints):
        plt.scatter(x, y, c=color_map[i], s=20, marker='o', label=joints_list[str(i)])
    
    plt.legend(bbox_to_anchor=(1,1))
    plt.axis("off")
    plt.show()

def plot_heatmaps(image, heatmaps):
    fig, axes = plt.subplots(2, 8, figsize=(16, 4))
    for i, ax in enumerate(axes.flat):
        ax.imshow(cv2.cvtColor(np.float32(image), cv2.COLOR_BGR2RGB))
        ax.imshow(heatmaps[:, :, i], cmap='jet', alpha=0.6)
        ax.set_title(joints_list[str(i)])
        ax.axis('off')
    
    plt.show()

# %%
# test_image = testdata[3700]
# input_image = preprocess_test_image(test_image)
input_image = cv2.imread(os.path.join(dataset_folder, 'cyclist-3.jpg')) / 255.0
predictions = model.predict(np.expand_dims(input_image, axis=0))
# Out:
# 1/1 [==============================] - 8s 8s/step

# %%
heatmaps = tf.squeeze(predictions)

plot_heatmaps(input_image, heatmaps)

# %% [markdown]
# ## Extract joints
# Above we have the predictions the model made based on each joint, lets now try to extract a joint from each heatmap

# %%
extract_and_plot_joints(input_image, heatmaps)

# %% [markdown]
# ## Data Augmentation
# Normally we could do this with Keras augmentation layers, but these are designed only for images - they don't handle our joints. Because of this we will need to do this manually. OpenCV, which we have used before, comes with a some neat functions for handling the images; `getRotationMatrix2D()` and `warpAffine()`, and `transform()` for the other properties.
#
# We will also need to put this into a .h5 file like previously with the full training data.

# %%
cyclist_data = []
for ann in data:
    if ann['for_training'] == 0: continue
    if 'bicycling' in ann['category']: cyclist_data.append(ann)

# %%
def affine_transform(image, joints, angle=0, scale=1.0, translation=(0, 0)):
    h,w = image.shape[:2]
    
    center = (w / 2, h / 2)
    matrix = cv2.getRotationMatrix2D(center, angle, scale)
    matrix[:, 2] += translation
    
    t_image = cv2.warpAffine(image, matrix, (w, h))
    
    pre_joints = np.hstack([joints, np.ones((joints.shape[0], 1))])
    t_joints = np.dot(matrix, pre_joints.T).T
    
    return t_image, t_joints

def augment_image(image, joints, prob=0.5):
    h,w = image.shape[:2]
    
    angle = random.uniform(-15, 15)

    image, joints = affine_transform(image, joints, angle, 1.0, (0,0))
    
    image = cv2.convertScaleAbs(
        image, 
        alpha=1.0 + random.uniform(-0.1, 0.1),
        beta=random.uniform(-0.2, 0.4) * 255,
    )
    
    if random.random() < prob:
        image = cv2.flip(image, 1) # flip horizontally
        joints[:, 0] = w - joints[:, 0] # flip x-coordinates
    
    return image, joints

def create_cyclist_dataset(dataset, name, augmentations_per_image=5):
    num_samples = len(dataset) * augmentations_per_image
    
    with h5py.File(os.path.join(mpii_folder,name + '.h5'), 'w') as f:
        img_dataset = f.create_dataset("images", (num_samples, 128, 128, 3), dtype='uint8') # IMG SIZE (128,128,3)
        heatmaps_dataset = f.create_dataset("heatmaps", (num_samples, 128, 128, 16), dtype='uint8') # IMG SIZE + joints
        
        index = 0
        for ann in dataset:
            img_path = os.path.join(image_folder, ann['filename'])
            objpos = (ann['approx_loc']['x'], ann['approx_loc']['y'])
            scale = ann['approx_loc']['scale']
            
            preprocessed_img, transform_params = preprocess_image(img_path, objpos, scale)
            adjusted_keypoints = adjust_keypoints(ann['joint_coords'], transform_params)
            
            for _ in range(augmentations_per_image):
                aug_image, aug_joints = augment_image(preprocessed_img, adjusted_keypoints)
                
                img_dataset[index] = aug_image
                heatmaps_dataset[index] = (generate_heatmap((128, 128), aug_joints / 128) * 255).astype(np.uint8) # scale to 0-255
                
                index += 1
            
            if index >= num_samples: break
    
    print(name + ".h5 successfully created")

create_cyclist_dataset(cyclist_data, 'cyclist_dataset', augmentations_per_image=7)
# Out:
# cyclist_dataset.h5 successfully created

# %% [markdown]
# ### Loading the dataset
# We repeat the process like before with loading the dataset and creating a TensorFlow dataset from it.

# %%
with h5py.File(os.path.join(mpii_folder, 'cyclist_dataset.h5'), 'r') as f:
    cd_images = np.array(f['images'], dtype=np.float16) / 255.0 # normalize the images to [0,1]
    cd_heatmaps = np.array(f['heatmaps'], dtype=np.float16) / 255.0 # normalize the heatmaps to [0,1]
    num_samples_cycling = cd_images.shape[0]

# %% [markdown]
# either like this:

# %%
cyclist_dataset = tf.data.Dataset.from_tensor_slices((cd_images, cd_heatmaps))

# %% [markdown]
# or like this:

# %%
def data_generator():
    for i in range(num_samples_cycling):
        yield cd_images[i], cd_heatmaps[i]

cyclist_dataset = tf.data.Dataset.from_generator(
    data_generator,
    output_signature=(
        tf.TensorSpec(shape=(128, 128, 3), dtype=tf.float16),
        tf.TensorSpec(shape=(128, 128, 16), dtype=tf.float16),
    )
)

# %%
train_ratio = 0.8
train_size = int(num_samples_cycling * train_ratio)

cyclist_train_data = cyclist_dataset.take(train_size).shuffle(num_samples, seed=42).batch(16).prefetch(tf.data.AUTOTUNE)
cyclist_val_data = cyclist_dataset.skip(train_size).batch(16).prefetch(tf.data.AUTOTUNE)
print(f"Train samples: {train_size}, Validation samples: {num_samples_cycling - train_size}")
# Out:
# Train samples: 3959, Validation samples: 990

# %%
model = keras.models.load_model('model_heatmap_t1_lr1e4-huber-mae_e100-train-val-early-reducelr.keras')

retrained_history = model.fit(
    cyclist_train_data,
    validation_data=cyclist_val_data,
    epochs=100,
    callbacks=[
        EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, verbose=1),
        ModelCheckpoint("best_heatmap_model.h5", monitor="val_loss", save_best_only=True),
        ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-7, verbose=1),
    ]
)

# %%
model.save('model_heatmap_data-aug_e100-early-reducelr.keras')
np.save('retrained_history.npy', retrained_history)
